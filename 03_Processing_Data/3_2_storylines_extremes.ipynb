# %% [markdown]
# ### The storylines for last year heatwave
# Task to get the different storylines and then plot them side by side.
# Also do something with wind because some people may be interested more in wind energy.
